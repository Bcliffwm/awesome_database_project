# %%
from google.colab import files

# Promp to upload service account key
uploaded = files.upload()
# Out:
#      <input type="file" id="files-43f1fb8b-f367-4418-bdfd-a9a9cad1ec81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43f1fb8b-f367-4418-bdfd-a9a9cad1ec81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# See if the file exists in /content
# !ls /content
# Out:
# amazing-database-project-ff12da6c1547.json  connect_bigquery.ipynb  sample_data

# %%
from google.cloud import bigquery
import os

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/content/amazing-database-project-ff12da6c1547.json'

# %%
client = bigquery.Client()

# %%
sql_query = """
  SELECT r.id, r.title, r.rating,
  n.calories, n.carbs, n.cholesterol, n.fiber, n.protein, n.sodium, n.sugar
  FROM recipes.recipes_data AS r
  INNER JOIN recipes.nutrients_dataset AS n
  ON r.id = n.recipe_id
  ORDER BY r.id ASC
  LIMIT 5
 """

# %%
query_job = client.query(sql_query)

# %%
for row in query_job.result():
  print(row)
# Out:
# Row((0, 'Ground Beef and Cabbage', 4.5, '228 kcal', '18 g', '50 mg', '7 g', '18 g', '191 mg', '10 g'), {'id': 0, 'title': 1, 'rating': 2, 'calories': 3, 'carbs': 4, 'cholesterol': 5, 'fiber': 6, 'protein': 7, 'sodium': 8, 'sugar': 9})
# Row((1, 'Old Fashioned Peach Cobbler', 4.6, '338 kcal', '44 g', '26 mg', '1 g', '2 g', '177 mg', '30 g'), {'id': 0, 'title': 1, 'rating': 2, 'calories': 3, 'carbs': 4, 'cholesterol': 5, 'fiber': 6, 'protein': 7, 'sodium': 8, 'sugar': 9})
# Row((2, 'St. Louis Toasted Ravioli', 4.5, '374 kcal', '39 g', '57 mg', '4 g', '11 g', '886 mg', '9 g'), {'id': 0, 'title': 1, 'rating': 2, 'calories': 3, 'carbs': 4, 'cholesterol': 5, 'fiber': 6, 'protein': 7, 'sodium': 8, 'sugar': 9})
# Row((4, 'Simple Fried Morel Mushrooms', 4.7, '46 kcal', '10 g', '1 mg', '0 g', '0 g', '219 mg', '8 g'), {'id': 0, 'title': 1, 'rating': 2, 'calories': 3, 'carbs': 4, 'cholesterol': 5, 'fiber': 6, 'protein': 7, 'sodium': 8, 'sugar': 9})
# ...
